# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import scipy.stats as st
import os.path
from os import path
import json

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_players_Titled = "output_data/players_Titled.csv"
output_data_players_DK =  "output_data/players_DK.csv"

titled_players_type = ["GM","WGM","IM","WIM","FM","WFM","NM","WNM","CM","WCM"]

# Range of latitudes and longitudes
# lat_range = (-90, 90)
# lng_range = (-180, 180)

# %%
# ***********************************
#
# LIMIT run once per 24 hours to get
# username list by country
#
# ***********************************

# country code # countries list resource https://en.wikipedia.org/wiki/ISO_3166-1_alpha-2
country = "DK" # DENMARK = DK

query_url = f"https://api.chess.com/pub/country/{country}/players"

print(f"Fetching player list for country {country}")

# Get player usernames for country
username_response = requests.get(query_url)
username_json = username_response.json()
username_json
# Out:
# Fetching player list for country DK
# {'players': ['-lange-',
#   '-toke-',
#   '00363',
#   '003h',
#   '00kkh00',
#   '00pultz',
#   '00skibsted',
#   '00sten',
#   '0202peth',
#   '03nipo',
#   '0412421353',
#   '0cent',
#   '0erekle0',
#   '0rlac',
#   '0rlactic',
#   '0rtoft40',
#   '0wlskar',
#   '10000t',
#   '100roses',
#   '1010ferry',
#   '101lmfa0',
#   '10kgcod',
#   '10tusind',
#   '1112410925',
#   '1137aplha',
#   '122fps',
#   '123098765',
#   '1233332225687539ppp',
#   '123bux',
#   '123ching123',
#   '123nor',
#   '123seconds',
#   '12banana',
#   '12latebread12',
#   '12yearsapawn',
#   '1337dk',
#   '133dk',
#   '13cris',
#   '13kaas31',
#   '14wolf',
#   '1555skak',
#   '1773v',
#   '1919andreas',
#   '1978thunderball',
#   '1994herman',
#   '1994toby',
#   '19953',
#   '19arki60',
#   '1bibliotekar',
#   '1d4bludgeoning',
#   '1dollarstack',
#   '1emanuel',
#   '1grabau',
#   '1hejsa1',
#   '1hhh',
#   '1karstenjensen2',
#   '1lasse1',
#   '1moak1',
#   '1mr_bojangles1',
#   '1ob1',
#   '1polo1',
#   '1redeye1',
#   '1ry1n',
#   '1sergejprotsenko2',
#   '1stquiz',
#   '1v1brormand',
#   '1_noahw',
#   '2000frb',
#   '2006viktor',
#   '200krstandard',
#   '2012jv',
#   '211161',
#   '21dinorex',
#   '2200ahj',
#   '2200sw87',
#   '2375',
#   '23dragons',
#   '23tobiase',
#   '2500benja',
#   '2581',
#   '270547',
#   '2bishopsvatelse',
#   '2bkrit',
#   '2goffice',
#   '2kemon',
#   '2mstolpe',
#   '2pac_gl',
#   '2shy2play',
#   '2virgil',
#   '30avash',
#   '321skakmat',
#   '321tja123',
#   '333sab',
#   '342wfdvwfd',
#   '360bishopyabish',
#   '3areaffsafjnkjnknk',
#   '3a_signe',
#   '3danton',
#   '3sandersson',
#   '3werck',
#   '41129',
#   '420butter',
#   '420chessyourmom',
#   '420ricepaper',
#   '43birte19',
#   '45k3',
#   '47denmark',
#   '47p19',
#   '4cashosten',
#   '4nt0n560',
#   '4o4_notfound',
#   '500iqkekw',
#   '51speedy',
#   '5500fbk',
#   '57iq',
#   '5empates',
#   '5headg4mer',
#   '610jens073',
#   '6333_2',
#   '64tim64',
#   '6500uldal',
#   '653726o',
#   '65mathias',
#   '66cestmoi',
#   '6760farup',
#   '68hk',
#   '69storm',
#   '8115',
#   '84ghutu',
#   '888warboys',
#   '9-q-lai',
#   '935303kr',
#   '96anders',
#   '96jonas96',
#   '96mark10',
#   '999mikkel',
#   '9colas99',
#   '9lasssss',
#   '9ls',
#   '9m02',
#   '9n3530ah3akr',
#   '9nazgul',
#   '9xs',
#   'a-l-o',
#   'a-vind',
#   'a05sysp',
#   'a3llo',
#   'a733737',
#   'a811',
#   'aa32',
#   'aabjerg00',
#   'aabysss',
#   'aadmv',
#   'aaen9',
#   'aagaard89',
#   'aagaard91',
#   'aagesigurd8',
#   'aagreen67',
#   'aahil04',
#   'aaj_88',
#   'aakob',
#   'aakos',
#   'aalborf',
#   'aamarmajeed',
#   'aamoney1',
#   'aandehesten',
#   'aandresson',
#   'aaor1912',
#   'aarhus11',
#   'aarlington',
#   'aaronabainza',
#   'aasasd728235',
#   'aaskov',
#   'aasrk',
#   'aat24bhy',
#   'aaurlov',
#   'ab-i',
#   'ab00ham',
#   'ab2258',
#   'abalslev',
#   'abalslev1',
#   'abananna',
#   'abananna2515464',
#   'abbativoli',
#   'abbzza',
#   'abdi1smail',
#   'abdigedi',
#   'abdisalam22',
#   'abdiyusuf2880',
#   'abdizaman',
#   'abdujafi',
#   'abdul2046',
#   'abdulhamid1234',
#   'abdulsulestropper',
#   'abe05e',
#   'abedard',
#   'abekrampe',
#   'abel99',
#   'abemad123',
#   'abemand93',
#   'abersej',
#   'abersejereenddig',
#   'abi-smj',
#   'abildgs',
#   'abisha91',
#   'abitsch',
#   'ableskewer',
#   'abmalag',
#   'abmannov',
#   'abnn',
#   'abnormaljoke',
#   'abnormalline',
#   'abodh1997',
#   'aboel',
#   'abrakadbra0',
#   'abralexis',
#   'abrasim',
#   'abruzz',
#   'abs3000',
#   'absl',
#   'absolutebeginner45',
#   'absq',
#   'abssprot',
#   'abstrakten',
#   'absudab',
#   'abtosse',
#   'abuabdu',
#   'abufox',
#   'abujafi',
#   'accessibilityguru',
#   'acd0106',
#   'acecph',
#   'aceinsl33ve',
#   'acelik1',
#   'acelivion',
#   'acenda',
#   'ace_ghost',
#   'acf76',
#   'acgd',
#   'ach49',
#   'achilleus24',
#   'achiraaz',
#   'acidbucket',
#   'acijub',
#   'aclausager',
#   'acol42',
#   'acomdk',
#   'across_thesea',
#   'actana',
#   'actualwizrd',
#   'actual_miley_cyrus',
#   'adaabrutyte',
#   'adalgas',
#   'adam67',
#   'adamauken',
#   'adambioue',
#   'adambistrup',
#   'adambn97',
#   'adambtw',
#   'adamclasen',
#   'adamdanyx',
#   'adamez',
#   'adamfeldt',
#   'adamflou1',
#   'adamfogarasi93',
#   'adamhenriksen',
#   'adamjespersen',
#   'adamliorf',
#   'adampittard',
#   'adamzkii',
#   'adam_haupthansen',
#   'adaonorgant',
#   'adaptnow',
#   'adarshchaudhary-3a',
#   'adelnobleza',
#   'adennxd',
#   'adesh46',
#   'adilmaroc10',
#   'adion',
#   'adismadi',
#   'adk51',
#   'adkons',
#   'admiral_ackbar123',
#   'adn2409',
#   'adnan0265',
#   'adonisgoes1337',
#   'adpllana',
#   'adri1626',
#   'adrianaolsen',
#   'adrianbrochner',
#   'adrianconstantind',
#   'adriandoranson',
#   'adriandwor',
#   'adrianexp',
#   'adrianiaros',
#   'adridas1',
#   'adridu2200',
#   'adrtinf',
#   'ads2612',
#   'adsbol',
#   'adsersen',
#   'advantage123',
#   'ad_libitum93',
#   'aeblefisk',
#   'aed_snegle',
#   'aegamer21',
#   'aegrath',
#   'aelleby',
#   'aeneas91234',
#   'aengdal',
#   'aettrup',
#   'afan3400',
#   'afanger',
#   'afeilberg',
#   'aff-26',
#   'affaldsskak',
#   'afferchess',
#   'afg1515',
#   'afghanmomand',
#   'afkgg',
#   'afn96',
#   'afragilekreature',
#   'afrasiab123',
#   'afrosnale',
#   'afshinbe',
#   'agapiqueen',
#   'agatun357',
#   'agerbo',
#   'agerboo',
#   'agerholm',
#   'agersnap',
#   'agfsuperfan',
#   'aggefar',
#   'aggeloscharal',
#   'agger15',
#   'aggr3gate',
#   'aggressiveballet',
#   'agimmustafi',
#   'agk91',
#   'agnes2006',
#   'agohh',
#   'agolf1',
#   'agr97',
#   'agraae',
#   'agrix',
#   'agryf',
#   'agso90',
#   'aguacongas',
#   'agurker5',
#   'agurkesalat',
#   'ah2507',
#   'ah2727',
#   'ahageskov',
#   'ahbrogaard',
#   'aheavypanda',
#   'ahjensen',
#   'ahm1953',
#   'ahmad237',
#   'ahmadbarsha',
#   'ahmadhadji',
#   'ahmadsabah313',
#   'ahmed9998',
#   'ahmedfayyad',
#   'ahmedhannan',
#   'ahmednassar122',
#   'ahoaj',
#   'ahskak',
#   'ahtipakkanen',
#   'ahund101',
#   'ai7ai',
#   'aicklasanielsen',
#   'aidaga90',
#   'aidentj',
#   'aightmaniger',
#   'ail0604',
#   'aimaslund',
#   'aimbotvict',
#   'aintnosushi',
#   'ainulindaie',
#   'aipm07',
#   'airago10',
#   'airsquadron',
#   'aisha7596',
#   'aiversen55',
#   'aizeoskar',
#   'aj3101',
#   'ajaku',
#   'ajala123',
#   'ajanthan111',
#   'ajanthankk',
#   'ajarporcupine',
#   'ajine',
#   'ajmalahadi',
#   'ajoejensen',
#   'ajoensen',
#   'ajp_003',
#   'aka173',
#   'akaimba',
#   'akame333',
#   'akapaviaa',
#   'akatrine',
#   'akayousef',
#   'akayukishiro',
#   'akazuk',
#   'akeleje121243',
#   'akerwall',
#   'akex64',
#   'akhi6669',
#   'akibaten',
#   'akigon',
#   'aking1991',
#   'akinom96',
#   'akirauchiha',
#   'akj89',
#   'akk2500',
#   'akl1234',
#   'akmentina',
#   'akmoller',
#   'akmunk',
#   'akruler',
#   'akrusem',
#   'akse1204',
#   'aksel1312',
#   'aksel650',
#   'akselbak-jensen',
#   'akselmanden',
#   'akselmundbjerg',
#   'akselwo',
#   'aksel_clemmensen',
#   'aksel_the_boi',
#   'aksjfasfnlkadmzfn',
#   'akuc',
#   'akvh',
#   'akwhideki',
#   'al1zzy',
#   'alabadin',
#   'aladdin227',
#   'alana2001',
#   'alangea',
#   'alavnader123',
#   'alba-mariemadsen',
#   'alba0167',
#   'albamunksgaard',
#   'alban51',
#   'albanian01',
#   'albankuci',
#   'albanviktor',
#   'albatrosdk',
#   'albehaps',
#   'albekko',
#   'albemanden',
#   'albericio',
#   'albert2106hansen',
#   'albert3460',
#   'albertbaerentsen',
#   'albertchristensen02',
#   'albertconradsen',
#   'alberte001',
#   'albertehammeken',
#   'albertekat',
#   'albertevibe',
#   'alberthesigvert',
#   'albertkjolby',
#   'albertlunde',
#   'albertmaktabi',
#   'albertodores',
#   'albertoheinz',
#   'albertolson',
#   'albertowner',
#   'alberto_20cm',
#   'albertstigsen',
#   'albertthal-jantzen',
#   'albertvb9',
#   'albertw21',
#   'albertwilhelm',
#   'albi1311',
#   'albin0065',
#   'albisaltojansen',
#   'alborzplaychess',
#   'aldrup91',
#   'aldwynhuxley',
#   'alec2906',
#   'alecbil',
#   'alecjames33',
#   'alecorni',
#   'alejandrobarr',
#   'alejandrogerling',
#   'alekbur1513',
#   'aleklk',
#   'aleksandarerboesse',
#   'aleksejiskold',
#   'aleksik22',
#   'alekspach',
#   'alekviggo',
#   'alenemalene',
#   'aleqjensen',
#   'aletos',
#   'alevarelab',
#   'alex07176hein',
#   'alex2218',
#   'alex589a',
#   'alex6806',
#   'alex6gg',
#   'alex709c',
#   'alex729b',
#   'alex91485',
#   'alex96120',
#   'alexancler',
#   'alexand69',
#   'alexandarbengtsson',
#   'alexander-d-knudsen',
#   'alexander2000',
#   'alexander21198',
#   'alexanderadser',
#   'alexanderah',
#   'alexanderanielsen',
#   'alexanderbblicher',
#   'alexanderbermann',
#   'alexanderbjorn',
#   'alexanderbretlau',
#   'alexanderckh',
#   'alexanderdalgaard',
#   'alexanderdenstore11',
#   'alexanderdewhurst78',
#   'alexanderdk',
#   'alexanderflis96',
#   'alexanderfozz',
#   'alexanderfrom',
#   'alexandergregil',
#   'alexanderhansen1',
#   'alexanderhinz',
#   'alexanderjagd',
#   'alexanderkert',
#   'alexanderkirkedal',
#   'alexanderkopke',
#   'alexanderkristensen',
#   'alexanderlyhne',
#   'alexanderm1312',
#   'alexandermulvad',
#   'alexanderrj',
#   'alexanderscherer',
#   'alexanderseiersen',
#   'alexanderskouby',
#   'alexandersterler',
#   'alexandertrolle',
#   'alexanderwelford',
#   'alexanderwredeelung',
#   'alexander_andersen',
#   'alexander_la',
#   'alexander_oxe',
#   'alexandraandhov',
#   'alexandraemilia',
#   'alexandru00',
#   'alexandruteodosiu',
#   'alexchess420',
#   'alexcoj',
#   'alexdvacr15',
#   'alexenzim',
#   'alexfflis',
#   'alexfighter17',
#   'alexfriis',
#   'alexherup',
#   'alexhywel',
#   'alexknemeth',
#   'alexl1nd',
#   'alexlarsen89',
#   'alexllk',
#   'alexmd15',
#   'alexmotoc',
#   'alexmunkhjort',
#   'alexornbo',
#   'alexpinkerton',
#   'alexringgaard',
#   'alexruiz1306',
#   'alexsommerlund',
#   'alexsvol',
#   'alexthebaest1',
#   'alextranx',
#   'alexuddi',
#   'alexusdk',
#   'alexwooller',
#   'alex_christensen',
#   'alex_varde',
#   'alfa987654321',
#   'alfepe',
#   'alfgaba',
#   'alfi0002',
#   'alfik11',
#   'alfouros',
#   'alfpha',
#   'alfr0309',
#   'alfr0387',
#   'alfred1006',
#   'alfred4140',
#   'alfredaqraou',
#   'alfredbl',
#   'alfreddorph',
#   'alfredjeppesen',
#   'alfredkristensen',
#   'alfredmlgaard',
#   'alfredraa',
#   'alfredschoubye',
#   'alfredsoevikolesen',
#   'alfredtusse',
#   'alfx0117',
#   'alf_joergensen',
#   'alhasan94',
#   'ali10042002',
#   'ali1665',
#   'ali2772',
#   'aliagerli',
#   'aliali147',
#   'alialush',
#   'aliasredpeberfrugt',
#   'aliberri',
#   'alibioue',
#   'alice8954',
#   'aliceblossom',
#   'aliceryhl',
#   'alidaaquaman',
#   'alievski',
#   'alimejren',
#   'alimustafi1',
#   'alinabaei',
#   'alinozhat',
#   'alipatron7',
#   'alis68',
#   'alisaleem2',
#   'alisidawi77',
#   'alitale89',
#   'alix2826',
#   'aliyus',
#   'ali_2828',
#   'ali_malekimehr',
#   'aljehans',
#   'aljohin',
#   'alk03',
#   'alkalomo',
#   'alkemade98',
#   'all514',
#   'alladin01',
#   'allan-ovesen',
#   'allanaagejensen',
#   'allanaxelsen',
#   'allangrnborg',
#   'allanhenneberg',
#   'allanhovaldt',
#   'allanhvass',
#   'allanibsen',
#   'allanjohny',
#   'allanjr1',
#   'allano3333',
#   'allanrocha',
#   'allansaber',
#   'allanskaarup',
#   'allanskak',
#   'allansonne',
#   'allanthomsen',
#   'allan_skak-1',
#   'allbeangurung',
#   'allblunderz',
#   'allbrainz',
#   'allegroprince',
#   'allen1969',
#   'allesvraa',
#   'allient',
#   'alliv94',
#   'allmolle',
#   'alloffence',
#   'allpeace007',
#   'allurchess',
#   'alm801',
#   'almaaal',
#   'almaaskaer',
#   'almabiermann',
#   'almaekehed',
#   'almafeline',
#   'almaskak',
#   'almatybjerg6262',
#   'alme92',
#   'alminta',
#   'almirrrrrytcb',
#   'almlund',
#   'almsc',
#   'alnor-kb',
#   'alperen941',
#   'alpez89',
#   'alpha-kitty',
#   'alr2200',
#   'alsing514',
#   'alsingclive',
#   'alstrup52',
#   'alstrupper',
#   'alsvv123',
#   'altaica1337',
#   'alterrelativt',
#   'altidallerede',
#   'altschuler',
#   'aludk',
#   'aluux163',
#   'alvall',
#   'alxcph',
#   'alxndrjoshua',
#   'alxras',
#   'alxskak',
#   'alykke',
#   'aly_tody',
#   'alzac',
#   'amadeus7',
#   'amajose12',
#   'amalie112',
#   'amalie1490',
#   'amalieberger',
#   'amalieellen',
#   'amaliepikkelort',
#   'amaliesvensson',
#   'amaliewardeh',
#   'amalie_chess',
#   'aman1236362',
#   'aman34842',
#   'aman4950',
#   'amandafar',
#   'amandaip',
#   'amandakris',
#   'amandaveile',
#   'amandus0',
#   'amarsind',
#   'amartinstoudemire',
#   'amat0',
#   'amaya0901',
#   'amazingfaustino',
#   'ambirk',
#   'ambitionrl',
#   'ambitiouschesstruth',
#   'ambrockdorff',
#   'ambulant',
#   'amburin',
#   'amcalud',
#   'amdihill',
#   'amegoro',
#   'amelietapdrup',
#   'ameliewildau',
#   'amey4047',
#   'amg1316',
#   'amhr',
#   'amich15',
#   'amin86467933456uchio',
#   'aminak11',
#   'aminelotfi',
#   'aminjensen',
#   'aminosyre',
#   'aminyahyaoui123',
#   'amir9917',
#   'amirabouzid',
#   'amirdauti',
#   'amirgogl',
#   'amirmol',
#   'amir_1991',
#   'amkin06',
#   'amnoerrelykke',
#   'amo9090',
#   'amoeslund',
#   'amood12',
#   'amorfna_ameba',
#   'ampa04',
#   'amsomenumber',
#   'amswerdlow',
#   'amthebestest',
#   'amva2020',
#   'amysticllama',
#   'am_x',
#   'anadvancingturtle',
#   'analblaster4000',
#   'analpounding69420',
#   'analyzer7',
#   'anamuser',
#   'anarkand',
#   'anas1551',
#   'anasjuhaiem',
#   'anasky123',
#   'anastasiafliudrenko',
#   'anastasiamadsen',
#   'anatoliipershuta',
#   'anbelen',
#   'ancientdream',
#   'ancienthomer',
#   'ancientlevel',
#   'and100906',
#   'andaramram',
#   'andbw',
#   'anddreas867',
#   'anddru',
#   'ande269f',
#   'andenkk',
#   'anderizzlecs',
#   'anderjensen',
#   'anderjw80',
#   'anderoth',
#   'anders-sonne',
#   'anders006',
#   'anders0405',
#   'anders066',
#   'anders1001',
#   'anders1217',
#   'anders1408',
#   'anders1709',
#   'anders2900',
#   'anders312',
#   'anders330',
#   'andersaaholm',
#   'andersasmussen',
#   'andersbalslev',
#   'andersbeltoft',
#   'andersberdiin',
#   'andersbjerggeder',
#   'andersbjerre',
#   'andersbohansen',
#   'andersbrol',
#   'andersbrund',
#   'anderscarlo',
#   'anderschar',
#   'anderschrist',
#   'andersditlev',
#   'andersdk12',
#   'andersdsoede',
#   'andersen0105',
#   'andersenp',
#   'andersessendrop',
#   'andersfaarup',
#   'andersfriis',
#   'andersgeisler',
#   'andersgudnason',
#   'andersh1',
#   'andersh42',
#   'andershauer',
#   'andershauge025',
#   'andershaulund369',
#   'andersholm-tygesen',
#   'andersholmrasmussen',
#   'andersholvad',
#   'andershusted',
#   'andersjaja',
#   'andersjakobsen',
#   'andersjrgensen',
#   'anderskauffmann12',
#   'anderskoch',
#   'anderskusk',
#   'anderslehnsdal',
#   'anderslj',
#   'anderslundkoch',
#   'andersmalling60',
#   'andersmdk',
#   'andersmeyerpetersen',
#   'andersmichaelnielsen',
#   'andersmk',
#   'andersml',
#   'andersnoer2',
#   'andersodgaard',
#   'andersp94',
#   'andersparsley',
#   'andersplambech',
#   'anderspth',
#   'andersrn',
#   'andersrohde',
#   'andersschjdt',
#   'andersseiji98',
#   'anderssimoni',
#   'anderssjensen',
#   'andersskov4',
#   'anderssmortensen',
#   'andersssv',
#   'andersstausholm05',
#   'andersstaxen',
#   'andersstrom',
#   'andersswagger',
#   'anderstherkelsen',
#   'anderstonnesen',
#   'andersvaran1',
#   'andersvesterborg',
#   'andersvisby',
#   'anderswang',
#   'anders_bc',
#   'anders_bork',
#   'anders_pc',
#   'anders_von_and',
#   'andfinbar',
#   'andj7777',
#   'andjoloss',
#   'andloev',
#   'andorduck',
#   'andpers',
#   'andr2206',
#   'andr261',
#   'andr265i',
#   'andr273f',
#   'andr297p',
#   'andr850g',
#   'andr9144',
#   'andre164219',
#   'andrea6334',
#   'andrea8717',
#   'andreabarghetti',
#   'andreagamst1',
#   'andreajfahmy',
#   'andreanda',
#   'andreas-er-sej',
#   'andreas0909',
#   'andreas2206',
#   'andreas2405',
#   'andreas40',
#   'andreas8889',
#   'andreas97valentin',
#   'andreasaarup',
#   'andreasahston',
#   'andreasbaykoenig',
#   'andreasbirk',
#   'andreasborgez',
#   'andreasbsv',
#   'andreasbvp',
#   'andreasdcd',
#   'andreasdenmark',
#   'andreasdk1993',
#   'andreasduun',
#   'andreasdyring',
#   'andreaselbke',
#   'andreasenclaus',
#   'andreasevers',
#   'andreasfisker03',
#   'andreasfrom',
#   'andreasgahner',
#   'andreasgimm',
#   'andreasgpp',
#   'andreashadsten',
#   'andreashald',
#   'andreashass',
#   'andreashenneberg',
#   'andreashoffhjort',
#   'andreashvass',
#   'andreasjohnezwin',
#   'andreask16',
#   'andreaskalmar',
#   'andreaskastrup',
#   'andreaskeergaard',
#   'andreaskleczewski',
#   'andreasknudsen',
#   'andreaskrist',
#   'andreasln123',
#   'andreasloeg',
#   'andreaslp1995',
#   'andreasmelsen',
#   'andreasmg13',
#   'andreasp555',
#   'andreaspade',
#   'andreasrafn',
#   'andreasrex1',
#   'andreasrp',
#   'andreasschroederdk',
#   'andreasskakchamp',
#   'andreasskeem',
#   'andreassode',
#   'andreassteffensen12',
#   'andreasstigkaer',
#   'andreasstobberup',
#   'andreaswind',
#   'andreas_eeg',
#   'andreas_koch',
#   'andreas_nielsen',
#   'andreas_nygaard',
#   'andreas_wulff',
#   'andrebauns',
#   'andrebeatz',
#   'andreeaioa',
#   'andrefalster',
#   'andrehazh',
#   'andrei1444',
#   'andreidarie',
#   'andreiilisei',
#   'andreip0pa',
#   'andreixwe',
#   'andrei_0',
#   'andrejdedic',
#   'andrej_dk',
#   'andrelle3000',
#   'andreluc147',
#   'andreniemeijer',
#   'andrergurgel88',
#   'andresen',
#   'andressagastume',
#   'andrevitalpardue',
#   'andrewgrove',
#   'andrewmarvel',
#   'andrewvinther',
#   'andrheeze',
#   'androfb',
#   'androkles69',
#   'andropov14',
#   'andros5',
#   'androugles',
#   'andrreossing',
#   'andsac',
#   ...]}

# %%
usernames_DK = []
for username in username_json["players"]:
    usernames_DK.append(username)
    
player_DK_dict = {    
    "username":usernames_DK
}
chessplayer_DK_df = pd.DataFrame(player_DK_dict)
chessplayer_DK_df.to_csv(output_data_players_DK, index=True,index_label="player_index") 
chessplayer_DK_df
# Out:
#            username
# 0           -lange-
# 1            -toke-
# 2             00363
# 3              003h
# 4           00kkh00
# ...             ...
# 20801        zymbia
# 20802         zyneh
# 20803     zzuckingz
# 20804  zzzznoahzzzz
# 20805           z_z
#
# [20806 rows x 1 columns]

# %%
# count number of usernames
len(usernames)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3265abb21fa9> in <module>
#       1 # count number of usernames
# ----> 2 len(usernames)
#
# NameError: name 'usernames' is not defined

# %%
def get_titledplayers_api(playertypes):
    url = "https://api.chess.com/pub/titled/"
    
    i = 0        
    players_data = []
    
    for playertype in playertypes:
        print(f"Index {str(i)} fetching player list for titled player type {playertype}")
    
        # Build query URL
        query_url = f"{url}{playertype}"

        # increment index counter
        i += 1

        # Get weather data    
        playertype_response = requests.get(query_url)
        playertype_json = playertype_response.json()
        players_data.append(playertype_json)        
        time.sleep(1)    
        
    return players_data

# %%
def get_playerdata_api(player_usernames):
    url = "https://api.chess.com/pub/player/"
    
    i = 0        
    player_data = []
    
    for player_username in player_usernames:
        print(f"Index {str(i)} fetching player data for player {player_username}")
    
        # Build query URL
        query_url = f"{url}{player_username}"

        # increment index counter
        i += 1

        # Get player data    
        try:
            player_response = requests.get(query_url)
            player_json = player_response.json()
            player_data.append(player_json)        
            time.sleep(1)    
        except:
            print("unexpected error")
        
        # if i > 10:
        #    break
    return player_data

# %%
playerslist_data = get_titledplayers_api(titled_players_type)
# Out:
# Index 0 fetching player list for titled player type GM
# Index 1 fetching player list for titled player type WGM
# Index 2 fetching player list for titled player type IM
# Index 3 fetching player list for titled player type WIM
# Index 4 fetching player list for titled player type FM
# Index 5 fetching player list for titled player type WFM
# Index 6 fetching player list for titled player type NM
# Index 7 fetching player list for titled player type WNM
# Index 8 fetching player list for titled player type CM
# Index 9 fetching player list for titled player type WCM

# %%
playerlist_index = 0
i = 0

player_usernames = []

for playerlist in playerslist_data:    
    for player in playerlist["players"]:        
        player_usernames.append(player)
        
    playerlist_index += 1

# %% [markdown]
# ```{
#   "avatar": "https://images.chesscomfiles.com/uploads/v1/user/14775486.9072453d.200x200o.50bb2d10a7d5.jpeg",
#   "player_id": 14775486,
#   "@id": "https://api.chess.com/pub/player/140mariam",
#   "url": "https://www.chess.com/member/140mariam",
#   "name": "Mariam Avetisyan",
#   "username": "140mariam",
#   "title": "WFM",
#   "followers": 56,
#   "country": "https://api.chess.com/pub/country/AM",
#   "last_online": 1609780423,
#   "joined": 1385829847,
#   "status": "premium",
#   "is_streamer": false
# }
# ```

# %%
len(player_usernames)
# Out:
# 9302

# %%
# check if output_data_file exists already, if it doesn't exist, do api call to get weather data
if (path.exists(output_data_players)):
    # ****************
    # pull prevously generated and saved output data from csv
    chessplayer_df = pd.read_csv(output_data_players)
else:    
    # run api calls for each chess.com username
    # this step is skipped if the output_data_file already exists
    # !!!!! DELETE CSV OUTPUT FILE to generate new playerdata    
    playerdata = get_playerdata_api(player_usernames)
    
    player_id = []
    username = []
    title = []
    followers = []
    country = []
    location = []
    last_online = []
    joined = []
    status = []
    is_streamer = []

    i = 0

    for player in playerdata: 
        try:
            un = player["username"]
            print(f"Index {i} processing player {un}")
            player_id.append(player["player_id"])
            username.append(player["username"])
            title.append(player["title"])
            followers.append(player["followers"])
            country.append(player["country"].replace("https://api.chess.com/pub/country/","")),
            if "location" in player.keys():
                location.append(player["location"])        
            else:
                location.append("")                
            last_online.append(player["last_online"])
            joined.append(player["joined"])
            status.append(player["status"])
            is_streamer.append(player["is_streamer"])
        except:
            print("unexpected error")

        i += 1 
        
    player_dict = {
        "player_id":player_id,
        "username":username,
        "title":title,
        "followers":followers,
        "country":country,
        "location":location,
        "last_online":last_online,
        "joined":joined,
        "status":status,
        "is_streamer":is_streamer
    }
    chessplayer_df = pd.DataFrame(player_dict)

    chessplayer_df.to_csv(output_data_players, index=True,index_label="player_index")

# %%
chessplayer_df
# Out:
#       player_index  player_id      username title  followers country  \
# 0                0   18800602         123lt    GM         32      CN
# 1                1   29499974      124chess    GM         79      RU
# 2                2   30610578      1977ivan    GM         95      RS
# 3                3   13013662     1stsecond    GM        734      LV
# 4                4   39230304      2nd_life    GM         22      CH
# ...            ...        ...           ...   ...        ...     ...
# 9295          9295   29980036       yashami   WCM         21      NP
# 9296          9296   67624176    yoriiallam   WCM         10      EG
# 9297          9297   86574494     zaineb218   WCM          3      TN
# 9298          9298   85888234       zarinur   WCM         15      KZ
# 9299          9299   34994758  zauraabdulla   WCM         25      MV
#
#         location  last_online      joined   status  is_streamer  \
# 0            NaN   1608465021  1410059361  premium        False
# 1     Красноярск   1609836300  1471316272  premium        False
# 2       Belgrade   1609872690  1477565847  premium        False
# 3           Riga   1609536323  1375617889  premium        False
# 4         Zurich   1609876221  1507311109  premium        False
# ...          ...          ...         ...      ...          ...
# 9295   Kathmandu   1594232302  1474135436  premium        False
# 9296         NaN   1609501122  1573057158  premium        False
# 9297     Tunisie   1609446669  1594630390  premium        False
# 9298         NaN   1609904817  1594013985  premium        False
# 9299         NaN   1603095902  1492940119  premium        False
#
#      last_online_converted joined_converted
# 0               12/20/2020         9/7/2014
# 1                 1/5/2021        8/16/2016
# 2                 1/5/2021       10/27/2016
# 3                 1/1/2021         8/4/2013
# 4                 1/5/2021        10/6/2017
# ...                    ...              ...
# 9295              7/8/2020        9/17/2016
# 9296              1/1/2021        11/6/2019
# 9297            12/31/2020        7/13/2020
# 9298              1/6/2021         7/6/2020
# 9299            10/19/2020        4/23/2017
#
# [9300 rows x 13 columns]
